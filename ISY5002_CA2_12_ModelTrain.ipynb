# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="0";

# %%
import tensorflow as tf

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#######################################################
# Model Training
# 11/09/2019 
#
#######################################################
import numpy as np
import sklearn.metrics as metrics
import os
from math import floor


from tensorflow.keras.callbacks import ModelCheckpoint,CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from ISY5002_CA2_02_ModelDefinitions import createModel, my_preprocess

from tensorflow.keras.applications.vgg16 import preprocess_input as VGG16_preprocess_input
from tensorflow.keras.applications.resnet50 import preprocess_input as ResNet50_preprocess_input
from tensorflow.keras.applications.inception_v3 import preprocess_input as InceptionV3_preprocess_input

# import sys

# defining global variables
DEBUG_MODE = False
image_path = "./Resized"
seed        = 29 # fix random seed for reproducibility
np.random.seed(seed)
optmz       = 'adam'    # optimizers.RMSprop(lr=0.0001)
modelnameBase   = 'CA2'
num_classes = 3

channel = 3
num_epochs = 100

# hyperparameters
bsize = 32
rng_rot = 0
rng_zoom = 0.1
rng_bright = [0.01, 0]
rng_channel = 0.1
opt_hflip = True
opt_vflip = False

def create_summarise_plot(size, channel, index = 0):
    imgrows = size
    imgclms = size
    model = createModel(imgrows, imgclms, channel, index) # for training
    # modelGo = createModel() # for final testing
    model.summary()

    # Plot structure of network
    #from tensorflow.keras.utils import plot_model
    #plot_model(model, to_file='ISY5002_CA2_NN_' + str(index) + '.pdf', show_shapes=True, show_layer_names=False, rankdir='TB') 

    return model

def createIterators(size, index=0):
    imgrows = size
    imgclms = size

    preprocessing_fn = my_preprocess
    if (index > 90):
        # Using pretrained datasets - have to use their preprocess functions
        if (index == 90):
            preprocessing_fn = VGG16_preprocess_input
        elif (index == 91):
            preprocessing_fn = ResNet50_preprocess_input
        elif (index == 92):
            preprocessing_fn = InceptionV3_preprocess_input
    datagen = ImageDataGenerator(preprocessing_function = preprocessing_fn)
    datagenTrain = ImageDataGenerator(preprocessing_function = preprocessing_fn, 
        rotation_range=rng_rot, zoom_range=rng_zoom, 
        horizontal_flip=opt_hflip, vertical_flip=opt_vflip) 
        #brightness_range = rng_bright, channel_shift_range = rng_channel)
    
    train_it = datagenTrain.flow_from_directory('./Resized/train/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=bsize, color_mode='rgb')
    val_it = datagen.flow_from_directory('./Resized/validation/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=bsize, color_mode='rgb')
    # test_it = datagen.flow_from_directory('./Resized/test/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=1, color_mode='rgb')

    n_train = sum([len(files) for r, d, files in os.walk('./Resized/train/')])
    n_val = sum([len(files) for r, d, files in os.walk('./Resized/validation/')])
    # n_test = sum([len(files) for r, d, files in os.walk('./Resized/test/')])

    batchX, batchy = train_it.next()
    print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))

    return train_it, val_it, n_train, n_val  



def main():

    # ------ CHANGE THESE ------
    index = 12
    size = 224
    # --------------------------


    modelname = modelnameBase + "_" + str(index) + "_" + str(size)

    # Create model and summary
    train_it, val_it, n_train, n_val= createIterators(size, index)
    model = create_summarise_plot(size, channel, index)

    # Create checkpoint for the training
    # This checkpoint performs model saving when
    # an epoch gives highest testing accuracy
    filepath        = modelname + ".hdf5"
    checkpoint      = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')

    # Log the epoch detail into csv
    csv_logger      = CSVLogger(modelname +'.csv')
    callbacks_list  = [checkpoint,csv_logger]
    
    # steps_per_epoch = total training data across all classes / batch size
    # validation_steps = number of batches in validation dataset defining 1 epoch
    model.fit_generator(
        train_it, steps_per_epoch=floor(n_train/bsize), 
        validation_data=val_it, 
        validation_steps=floor(n_val/bsize),
        epochs=num_epochs, callbacks = callbacks_list )

main()
# Out:
# WARNING:tensorflow:From C:\Users\Wilson\Data_Analytics\Master in IS Course\Master in IS Course\Pattern Recognition System\Pattern Recognition CA2\Wilson\ISY5002_CA2_02_ModelDefinitions.py:156: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.
#
# Found 2496 images belonging to 3 classes.
# Found 624 images belonging to 3 classes.
# Batch shape=(32, 224, 224, 3), min=-1.841, max=2.330
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 128)     3584
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 128)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 128)     0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 112, 112, 128)     512
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 256)     295168
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 256)     0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 256)       1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 256)       1638656
# _________________________________________________________________
# activation_2 (Activation)    (None, 56, 56, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# flatten (Flatten)            (None, 200704)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               102760960
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 104,952,963
# Trainable params: 104,949,123
# Non-trainable params: 3,840
# _________________________________________________________________
# Epoch 1/100
# 78/78 [==============================] - 32s 405ms/step - loss: 2.4792 - acc: 0.3754 - val_loss: 2.0855 - val_acc: 0.4375
# Epoch 2/100
# 78/78 [==============================] - 20s 257ms/step - loss: 2.3066 - acc: 0.3950 - val_loss: 2.3016 - val_acc: 0.3651
# Epoch 3/100
# 78/78 [==============================] - 21s 274ms/step - loss: 2.1459 - acc: 0.4054 - val_loss: 2.0256 - val_acc: 0.3947
# Epoch 4/100
# 78/78 [==============================] - 21s 270ms/step - loss: 2.0185 - acc: 0.4447 - val_loss: 1.9809 - val_acc: 0.4062
# Epoch 5/100
# 78/78 [==============================] - 22s 287ms/step - loss: 1.8864 - acc: 0.4852 - val_loss: 1.8695 - val_acc: 0.4539
# Epoch 6/100
# 78/78 [==============================] - 23s 293ms/step - loss: 1.7598 - acc: 0.5405 - val_loss: 1.6878 - val_acc: 0.5658
# Epoch 7/100
# 78/78 [==============================] - 23s 290ms/step - loss: 1.6831 - acc: 0.5625 - val_loss: 1.5693 - val_acc: 0.6349
# Epoch 8/100
# 78/78 [==============================] - 22s 286ms/step - loss: 1.5883 - acc: 0.5982 - val_loss: 1.4639 - val_acc: 0.6530
# Epoch 9/100
# 78/78 [==============================] - 21s 275ms/step - loss: 1.5081 - acc: 0.6118 - val_loss: 1.4581 - val_acc: 0.6069
# Epoch 10/100
# 78/78 [==============================] - 22s 286ms/step - loss: 1.4808 - acc: 0.6178 - val_loss: 1.3832 - val_acc: 0.6711
# Epoch 11/100
# 78/78 [==============================] - 22s 276ms/step - loss: 1.3908 - acc: 0.6498 - val_loss: 1.4518 - val_acc: 0.6283
# Epoch 12/100
# 78/78 [==============================] - 23s 293ms/step - loss: 1.3417 - acc: 0.6599 - val_loss: 1.2604 - val_acc: 0.6891
# Epoch 13/100
# 78/78 [==============================] - 22s 277ms/step - loss: 1.2991 - acc: 0.6739 - val_loss: 1.2343 - val_acc: 0.6859
# Epoch 14/100
# 78/78 [==============================] - 23s 291ms/step - loss: 1.2691 - acc: 0.6799 - val_loss: 1.1788 - val_acc: 0.7171
# Epoch 15/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.2364 - acc: 0.6827 - val_loss: 1.3476 - val_acc: 0.6201
# Epoch 16/100
# 78/78 [==============================] - 23s 292ms/step - loss: 1.1951 - acc: 0.7031 - val_loss: 1.1496 - val_acc: 0.7188
# Epoch 17/100
# 78/78 [==============================] - 22s 287ms/step - loss: 1.1481 - acc: 0.7139 - val_loss: 1.0681 - val_acc: 0.7352
# Epoch 18/100
# 78/78 [==============================] - 23s 291ms/step - loss: 1.1190 - acc: 0.7216 - val_loss: 1.0600 - val_acc: 0.7385
# Epoch 19/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.0811 - acc: 0.7280 - val_loss: 1.0556 - val_acc: 0.7336
# Epoch 20/100
# 78/78 [==============================] - 22s 287ms/step - loss: 1.0315 - acc: 0.7352 - val_loss: 1.0020 - val_acc: 0.7549
# Epoch 21/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.9947 - acc: 0.7540 - val_loss: 1.0793 - val_acc: 0.7039
# Epoch 22/100
# 78/78 [==============================] - 22s 276ms/step - loss: 0.9794 - acc: 0.7600 - val_loss: 1.0332 - val_acc: 0.7220
# Epoch 23/100
# 78/78 [==============================] - 23s 289ms/step - loss: 0.9335 - acc: 0.7776 - val_loss: 0.9532 - val_acc: 0.7648
# Epoch 24/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.9253 - acc: 0.7640 - val_loss: 0.9823 - val_acc: 0.7368
# Epoch 25/100
# 78/78 [==============================] - 22s 278ms/step - loss: 0.8966 - acc: 0.7776 - val_loss: 1.0825 - val_acc: 0.7007
# Epoch 26/100
# 78/78 [==============================] - 23s 290ms/step - loss: 0.8667 - acc: 0.7909 - val_loss: 0.9280 - val_acc: 0.7697
# Epoch 27/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.8543 - acc: 0.7845 - val_loss: 1.0038 - val_acc: 0.7500
# Epoch 28/100
# 78/78 [==============================] - 23s 291ms/step - loss: 0.7808 - acc: 0.8165 - val_loss: 0.8264 - val_acc: 0.7944
# Epoch 29/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.7815 - acc: 0.8125 - val_loss: 0.8892 - val_acc: 0.7714
# Epoch 30/100
# 78/78 [==============================] - 22s 276ms/step - loss: 0.7697 - acc: 0.8257 - val_loss: 0.9535 - val_acc: 0.7533
# Epoch 31/100
# 78/78 [==============================] - 21s 276ms/step - loss: 0.7745 - acc: 0.8177 - val_loss: 0.9435 - val_acc: 0.7500
# Epoch 32/100
# 78/78 [==============================] - 22s 278ms/step - loss: 0.7538 - acc: 0.8217 - val_loss: 0.9240 - val_acc: 0.7533
# Epoch 33/100
# 78/78 [==============================] - 22s 278ms/step - loss: 0.7163 - acc: 0.8438 - val_loss: 0.8436 - val_acc: 0.7780
# Epoch 34/100
# 78/78 [==============================] - 23s 294ms/step - loss: 0.6838 - acc: 0.8478 - val_loss: 0.8419 - val_acc: 0.7961
# Epoch 35/100
# 78/78 [==============================] - 22s 287ms/step - loss: 0.6982 - acc: 0.8442 - val_loss: 0.7545 - val_acc: 0.8257
# Epoch 36/100
# 78/78 [==============================] - 21s 275ms/step - loss: 1.1493 - acc: 0.7372 - val_loss: 1.7628 - val_acc: 0.5444
# Epoch 37/100
# 78/78 [==============================] - 21s 275ms/step - loss: 1.1047 - acc: 0.7881 - val_loss: 1.1395 - val_acc: 0.7072
# Epoch 38/100
# 78/78 [==============================] - 22s 276ms/step - loss: 0.9077 - acc: 0.8165 - val_loss: 0.9362 - val_acc: 0.7812
# Epoch 39/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.7738 - acc: 0.8421 - val_loss: 0.8615 - val_acc: 0.7862
# Epoch 40/100
# 78/78 [==============================] - 22s 277ms/step - loss: 0.7460 - acc: 0.8281 - val_loss: 0.8482 - val_acc: 0.8092
# Epoch 41/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.7067 - acc: 0.8546 - val_loss: 1.0004 - val_acc: 0.7418
# Epoch 42/100
# 78/78 [==============================] - 22s 276ms/step - loss: 0.7049 - acc: 0.8470 - val_loss: 0.8312 - val_acc: 0.8109
# Epoch 43/100
# 78/78 [==============================] - 22s 288ms/step - loss: 0.6178 - acc: 0.8722 - val_loss: 0.6621 - val_acc: 0.8635
# Epoch 44/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.7070 - acc: 0.8570 - val_loss: 1.5818 - val_acc: 0.6316
# Epoch 45/100
# 78/78 [==============================] - 21s 274ms/step - loss: 0.8192 - acc: 0.8490 - val_loss: 0.8092 - val_acc: 0.8339
# Epoch 46/100
# 78/78 [==============================] - 22s 277ms/step - loss: 0.6467 - acc: 0.8790 - val_loss: 0.7708 - val_acc: 0.8487
# Epoch 47/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.6579 - acc: 0.8678 - val_loss: 0.8627 - val_acc: 0.7911
# Epoch 48/100
# 78/78 [==============================] - 21s 276ms/step - loss: 0.5859 - acc: 0.8810 - val_loss: 0.7581 - val_acc: 0.8339
# Epoch 49/100
# 78/78 [==============================] - 23s 291ms/step - loss: 0.5939 - acc: 0.8750 - val_loss: 0.7117 - val_acc: 0.8306
# Epoch 50/100
# 78/78 [==============================] - 23s 295ms/step - loss: 1.0114 - acc: 0.7921 - val_loss: 1.4537 - val_acc: 0.7072
# Epoch 51/100
# 78/78 [==============================] - 22s 279ms/step - loss: 1.0335 - acc: 0.8253 - val_loss: 1.0786 - val_acc: 0.7878
# Epoch 52/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.8325 - acc: 0.8530 - val_loss: 0.8103 - val_acc: 0.8355
# Epoch 53/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.6614 - acc: 0.8894 - val_loss: 1.1175 - val_acc: 0.7286
# Epoch 54/100
# 78/78 [==============================] - 22s 278ms/step - loss: 0.7223 - acc: 0.8574 - val_loss: 2.1451 - val_acc: 0.6299
# Epoch 55/100
# 78/78 [==============================] - 22s 281ms/step - loss: 1.0264 - acc: 0.7937 - val_loss: 1.0978 - val_acc: 0.7862
# Epoch 56/100
# 78/78 [==============================] - 22s 280ms/step - loss: 1.0412 - acc: 0.8065 - val_loss: 1.0980 - val_acc: 0.7812
# Epoch 57/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.9052 - acc: 0.8337 - val_loss: 1.0170 - val_acc: 0.7878
# Epoch 58/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.7912 - acc: 0.8510 - val_loss: 1.2681 - val_acc: 0.6776
# Epoch 59/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.7516 - acc: 0.8530 - val_loss: 1.0177 - val_acc: 0.7599
# Epoch 60/100
# 78/78 [==============================] - 22s 277ms/step - loss: 0.6965 - acc: 0.8802 - val_loss: 1.0149 - val_acc: 0.7451
# Epoch 61/100
# 78/78 [==============================] - 22s 277ms/step - loss: 0.8460 - acc: 0.8369 - val_loss: 2.0403 - val_acc: 0.5378
# Epoch 62/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.2859 - acc: 0.7532 - val_loss: 1.4524 - val_acc: 0.6908
# Epoch 63/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.1986 - acc: 0.7973 - val_loss: 1.1756 - val_acc: 0.8010
# Epoch 64/100
# 78/78 [==============================] - 21s 274ms/step - loss: 0.9883 - acc: 0.8369 - val_loss: 1.0108 - val_acc: 0.8076
# Epoch 65/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.9418 - acc: 0.8349 - val_loss: 1.3033 - val_acc: 0.7368
# Epoch 66/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.9739 - acc: 0.8482 - val_loss: 0.9723 - val_acc: 0.8306
# Epoch 67/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.9711 - acc: 0.8357 - val_loss: 1.0859 - val_acc: 0.7911
# Epoch 68/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.0720 - acc: 0.8089 - val_loss: 2.1628 - val_acc: 0.5132
# Epoch 69/100
# 78/78 [==============================] - 21s 271ms/step - loss: 1.4460 - acc: 0.7155 - val_loss: 1.3867 - val_acc: 0.6694
# Epoch 70/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.3468 - acc: 0.7340 - val_loss: 1.2907 - val_acc: 0.7385
# Epoch 71/100
# 78/78 [==============================] - 21s 270ms/step - loss: 1.5644 - acc: 0.6767 - val_loss: 1.4677 - val_acc: 0.7171
# Epoch 72/100
# 78/78 [==============================] - 21s 273ms/step - loss: 1.4686 - acc: 0.7380 - val_loss: 1.7875 - val_acc: 0.6382
# Epoch 73/100
# 78/78 [==============================] - 21s 270ms/step - loss: 1.6183 - acc: 0.7312 - val_loss: 1.6300 - val_acc: 0.7023
# Epoch 74/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.3904 - acc: 0.7700 - val_loss: 1.3721 - val_acc: 0.7533
# Epoch 75/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.1647 - acc: 0.8189 - val_loss: 1.2024 - val_acc: 0.7368
# Epoch 76/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.2459 - acc: 0.7668 - val_loss: 1.2711 - val_acc: 0.7648
# Epoch 77/100
# 78/78 [==============================] - 21s 270ms/step - loss: 1.2281 - acc: 0.7552 - val_loss: 1.4755 - val_acc: 0.6283
# Epoch 78/100
# 78/78 [==============================] - 22s 276ms/step - loss: 1.1332 - acc: 0.7825 - val_loss: 1.1004 - val_acc: 0.7714
# Epoch 79/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.9562 - acc: 0.8209 - val_loss: 0.9074 - val_acc: 0.8240
# Epoch 80/100
# 78/78 [==============================] - 21s 274ms/step - loss: 0.8489 - acc: 0.8450 - val_loss: 0.8392 - val_acc: 0.8174
# Epoch 81/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.7181 - acc: 0.8626 - val_loss: 0.7938 - val_acc: 0.8339
# Epoch 82/100
# 78/78 [==============================] - 21s 275ms/step - loss: 0.6640 - acc: 0.8762 - val_loss: 0.7059 - val_acc: 0.8553
# Epoch 83/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.6136 - acc: 0.8762 - val_loss: 0.7282 - val_acc: 0.8322
# Epoch 84/100
# 78/78 [==============================] - 23s 291ms/step - loss: 0.6079 - acc: 0.8854 - val_loss: 0.6721 - val_acc: 0.8651
# Epoch 85/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.8337 - acc: 0.8269 - val_loss: 2.5173 - val_acc: 0.5411
# Epoch 86/100
# 78/78 [==============================] - 21s 275ms/step - loss: 1.1991 - acc: 0.7897 - val_loss: 1.1301 - val_acc: 0.7928
# Epoch 87/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.9876 - acc: 0.8442 - val_loss: 1.6811 - val_acc: 0.6102
# Epoch 88/100
# 78/78 [==============================] - 21s 273ms/step - loss: 1.0433 - acc: 0.8205 - val_loss: 0.9666 - val_acc: 0.8602
# Epoch 89/100
# 78/78 [==============================] - 22s 281ms/step - loss: 0.8298 - acc: 0.8718 - val_loss: 0.8277 - val_acc: 0.8536
# Epoch 90/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.7452 - acc: 0.8774 - val_loss: 1.0329 - val_acc: 0.7418
# Epoch 91/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.6577 - acc: 0.8882 - val_loss: 0.7669 - val_acc: 0.8569
# Epoch 92/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.6320 - acc: 0.8874 - val_loss: 0.8127 - val_acc: 0.8141
# Epoch 93/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.6170 - acc: 0.8850 - val_loss: 0.7266 - val_acc: 0.8388
# Epoch 94/100
# 78/78 [==============================] - 21s 273ms/step - loss: 1.8336 - acc: 0.6322 - val_loss: 2.5448 - val_acc: 0.5312
# Epoch 95/100
# 78/78 [==============================] - 21s 269ms/step - loss: 2.1149 - acc: 0.6310 - val_loss: 2.0589 - val_acc: 0.6036
# Epoch 96/100
# 78/78 [==============================] - 22s 278ms/step - loss: 1.7981 - acc: 0.7376 - val_loss: 1.7342 - val_acc: 0.7105
# Epoch 97/100
# 78/78 [==============================] - 21s 270ms/step - loss: 1.5627 - acc: 0.7716 - val_loss: 1.6676 - val_acc: 0.6974
# Epoch 98/100
# 78/78 [==============================] - 21s 275ms/step - loss: 1.5424 - acc: 0.7612 - val_loss: 1.4491 - val_acc: 0.7582
# Epoch 99/100
# 78/78 [==============================] - 21s 270ms/step - loss: 1.3096 - acc: 0.8217 - val_loss: 1.3080 - val_acc: 0.7829
# Epoch 100/100
# 78/78 [==============================] - 21s 271ms/step - loss: 1.1442 - acc: 0.8490 - val_loss: 1.2992 - val_acc: 0.7516
