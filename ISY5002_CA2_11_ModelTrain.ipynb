# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="0";

# %%
import tensorflow as tf

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#######################################################
# Model Training
# 11/09/2019 
#
#######################################################
import numpy as np
import sklearn.metrics as metrics
import os
from math import floor


from tensorflow.keras.callbacks import ModelCheckpoint,CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from ISY5002_CA2_02_ModelDefinitions import createModel, my_preprocess

from tensorflow.keras.applications.vgg16 import preprocess_input as VGG16_preprocess_input
from tensorflow.keras.applications.resnet50 import preprocess_input as ResNet50_preprocess_input
from tensorflow.keras.applications.inception_v3 import preprocess_input as InceptionV3_preprocess_input

# import sys

# defining global variables
DEBUG_MODE = False
image_path = "./Resized"
seed        = 29 # fix random seed for reproducibility
np.random.seed(seed)
optmz       = 'adam'    # optimizers.RMSprop(lr=0.0001)
modelnameBase   = 'CA2'
num_classes = 3

channel = 3
num_epochs = 100

# hyperparameters
bsize = 32
rng_rot = 0
rng_zoom = 0.1
rng_bright = [0.01, 0]
rng_channel = 0.1
opt_hflip = True
opt_vflip = False

def create_summarise_plot(size, channel, index = 0):
    imgrows = size
    imgclms = size
    model = createModel(imgrows, imgclms, channel, index) # for training
    # modelGo = createModel() # for final testing
    model.summary()

    # Plot structure of network
    #from tensorflow.keras.utils import plot_model
    #plot_model(model, to_file='ISY5002_CA2_NN_' + str(index) + '.pdf', show_shapes=True, show_layer_names=False, rankdir='TB') 

    return model

def createIterators(size, index=0):
    imgrows = size
    imgclms = size

    preprocessing_fn = my_preprocess
    if (index > 90):
        # Using pretrained datasets - have to use their preprocess functions
        if (index == 90):
            preprocessing_fn = VGG16_preprocess_input
        elif (index == 91):
            preprocessing_fn = ResNet50_preprocess_input
        elif (index == 92):
            preprocessing_fn = InceptionV3_preprocess_input
    datagen = ImageDataGenerator(preprocessing_function = preprocessing_fn)
    datagenTrain = ImageDataGenerator(preprocessing_function = preprocessing_fn, 
        rotation_range=rng_rot, zoom_range=rng_zoom, 
        horizontal_flip=opt_hflip, vertical_flip=opt_vflip) 
        #brightness_range = rng_bright, channel_shift_range = rng_channel)
    
    train_it = datagenTrain.flow_from_directory('./Resized/train/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=bsize, color_mode='rgb')
    val_it = datagen.flow_from_directory('./Resized/validation/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=bsize, color_mode='rgb')
    # test_it = datagen.flow_from_directory('./Resized/test/', class_mode='categorical', target_size=(imgrows, imgclms), batch_size=1, color_mode='rgb')

    n_train = sum([len(files) for r, d, files in os.walk('./Resized/train/')])
    n_val = sum([len(files) for r, d, files in os.walk('./Resized/validation/')])
    # n_test = sum([len(files) for r, d, files in os.walk('./Resized/test/')])

    batchX, batchy = train_it.next()
    print('Batch shape=%s, min=%.3f, max=%.3f' % (batchX.shape, batchX.min(), batchX.max()))

    return train_it, val_it, n_train, n_val  



def main():

    # ------ CHANGE THESE ------
    index = 11
    size = 224
    # --------------------------


    modelname = modelnameBase + "_" + str(index) + "_" + str(size)

    # Create model and summary
    train_it, val_it, n_train, n_val= createIterators(size, index)
    model = create_summarise_plot(size, channel, index)

    # Create checkpoint for the training
    # This checkpoint performs model saving when
    # an epoch gives highest testing accuracy
    filepath        = modelname + ".hdf5"
    checkpoint      = ModelCheckpoint(filepath, monitor='val_acc', verbose=0, save_best_only=True, mode='max')

    # Log the epoch detail into csv
    csv_logger      = CSVLogger(modelname +'.csv')
    callbacks_list  = [checkpoint,csv_logger]
    
    # steps_per_epoch = total training data across all classes / batch size
    # validation_steps = number of batches in validation dataset defining 1 epoch
    model.fit_generator(
        train_it, steps_per_epoch=floor(n_train/bsize), 
        validation_data=val_it, 
        validation_steps=floor(n_val/bsize),
        epochs=num_epochs, callbacks = callbacks_list )

main()
# Out:
# WARNING:tensorflow:From C:\Users\Wilson\Data_Analytics\Master in IS Course\Master in IS Course\Pattern Recognition System\Pattern Recognition CA2\Wilson\ISY5002_CA2_02_ModelDefinitions.py:156: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.
#
# Found 2496 images belonging to 3 classes.
# Found 624 images belonging to 3 classes.
# Batch shape=(32, 224, 224, 3), min=-1.841, max=2.330
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 112, 112, 64)      256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       409728
# _________________________________________________________________
# activation_2 (Activation)    (None, 56, 56, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               25690368
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 192)               49344
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 192)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 192)               768
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 26,270,787
# Trainable params: 26,268,739
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/100
# 78/78 [==============================] - 26s 328ms/step - loss: 1.9564 - acc: 0.3674 - val_loss: 1.6063 - val_acc: 0.4260
# Epoch 2/100
# 78/78 [==============================] - 21s 269ms/step - loss: 1.7788 - acc: 0.4058 - val_loss: 1.5511 - val_acc: 0.4671
# Epoch 3/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.6203 - acc: 0.4583 - val_loss: 1.4397 - val_acc: 0.5329
# Epoch 4/100
# 78/78 [==============================] - 21s 271ms/step - loss: 1.5268 - acc: 0.4864 - val_loss: 1.3613 - val_acc: 0.5855
# Epoch 5/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.4093 - acc: 0.5521 - val_loss: 1.3098 - val_acc: 0.6316
# Epoch 6/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.3242 - acc: 0.5861 - val_loss: 1.2056 - val_acc: 0.6694
# Epoch 7/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.2441 - acc: 0.6170 - val_loss: 1.1781 - val_acc: 0.6727
# Epoch 8/100
# 78/78 [==============================] - 21s 267ms/step - loss: 1.2257 - acc: 0.6206 - val_loss: 1.2062 - val_acc: 0.6447
# Epoch 9/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.1643 - acc: 0.6410 - val_loss: 1.0964 - val_acc: 0.7023
# Epoch 10/100
# 78/78 [==============================] - 21s 267ms/step - loss: 1.1029 - acc: 0.6763 - val_loss: 1.1117 - val_acc: 0.6464
# Epoch 11/100
# 78/78 [==============================] - 21s 274ms/step - loss: 1.0617 - acc: 0.7007 - val_loss: 1.0051 - val_acc: 0.7155
# Epoch 12/100
# 78/78 [==============================] - 21s 272ms/step - loss: 1.0281 - acc: 0.6911 - val_loss: 0.9601 - val_acc: 0.7352
# Epoch 13/100
# 78/78 [==============================] - 21s 268ms/step - loss: 1.0094 - acc: 0.7087 - val_loss: 0.9374 - val_acc: 0.7319
# Epoch 14/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.9680 - acc: 0.7232 - val_loss: 0.9415 - val_acc: 0.7549
# Epoch 15/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.9369 - acc: 0.7240 - val_loss: 0.9312 - val_acc: 0.7270
# Epoch 16/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.8830 - acc: 0.7544 - val_loss: 0.9532 - val_acc: 0.7204
# Epoch 17/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.8619 - acc: 0.7612 - val_loss: 0.8881 - val_acc: 0.7401
# Epoch 18/100
# 78/78 [==============================] - 22s 277ms/step - loss: 0.8524 - acc: 0.7532 - val_loss: 0.8379 - val_acc: 0.7780
# Epoch 19/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.8330 - acc: 0.7716 - val_loss: 0.8206 - val_acc: 0.7664
# Epoch 20/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.7865 - acc: 0.7812 - val_loss: 0.8192 - val_acc: 0.7664
# Epoch 21/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.7740 - acc: 0.7905 - val_loss: 0.8114 - val_acc: 0.7829
# Epoch 22/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.7309 - acc: 0.8073 - val_loss: 0.7835 - val_acc: 0.7681
# Epoch 23/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.6978 - acc: 0.8105 - val_loss: 0.7821 - val_acc: 0.7961
# Epoch 24/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.6962 - acc: 0.8157 - val_loss: 0.8311 - val_acc: 0.7780
# Epoch 25/100
# 78/78 [==============================] - 21s 274ms/step - loss: 0.6664 - acc: 0.8237 - val_loss: 0.7064 - val_acc: 0.8273
# Epoch 26/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.6713 - acc: 0.8253 - val_loss: 0.7974 - val_acc: 0.7993
# Epoch 27/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.6268 - acc: 0.8377 - val_loss: 0.6997 - val_acc: 0.8322
# Epoch 28/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.5913 - acc: 0.8542 - val_loss: 0.6725 - val_acc: 0.8388
# Epoch 29/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.6170 - acc: 0.8498 - val_loss: 0.8719 - val_acc: 0.7582
# Epoch 30/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.5865 - acc: 0.8558 - val_loss: 0.6779 - val_acc: 0.8355
# Epoch 31/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.5441 - acc: 0.8766 - val_loss: 0.8386 - val_acc: 0.7796
# Epoch 32/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.8177 - acc: 0.8009 - val_loss: 2.6221 - val_acc: 0.4852
# Epoch 33/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.9525 - acc: 0.7728 - val_loss: 1.0363 - val_acc: 0.7155
# Epoch 34/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.7684 - acc: 0.8381 - val_loss: 0.8029 - val_acc: 0.8010
# Epoch 35/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.6556 - acc: 0.8622 - val_loss: 0.7162 - val_acc: 0.8306
# Epoch 36/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.6053 - acc: 0.8706 - val_loss: 0.7465 - val_acc: 0.8224
# Epoch 37/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.5878 - acc: 0.8766 - val_loss: 0.7076 - val_acc: 0.8454
# Epoch 38/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.5570 - acc: 0.8822 - val_loss: 0.7771 - val_acc: 0.8141
# Epoch 39/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.5338 - acc: 0.8866 - val_loss: 0.7240 - val_acc: 0.8191
# Epoch 40/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.5046 - acc: 0.8930 - val_loss: 1.7561 - val_acc: 0.5905
# Epoch 41/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.8848 - acc: 0.7640 - val_loss: 0.9068 - val_acc: 0.7697
# Epoch 42/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.7384 - acc: 0.8345 - val_loss: 0.7244 - val_acc: 0.8421
# Epoch 43/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.5837 - acc: 0.8854 - val_loss: 0.6640 - val_acc: 0.8553
# Epoch 44/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.5539 - acc: 0.8810 - val_loss: 0.7284 - val_acc: 0.8257
# Epoch 45/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.5056 - acc: 0.8958 - val_loss: 0.6731 - val_acc: 0.8454
# Epoch 46/100
# 78/78 [==============================] - 21s 274ms/step - loss: 0.4582 - acc: 0.9087 - val_loss: 0.6487 - val_acc: 0.8701
# Epoch 47/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.4505 - acc: 0.9127 - val_loss: 0.6405 - val_acc: 0.8618
# Epoch 48/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.4502 - acc: 0.9115 - val_loss: 0.7001 - val_acc: 0.8355
# Epoch 49/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.4680 - acc: 0.8990 - val_loss: 0.6117 - val_acc: 0.8520
# Epoch 50/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.3879 - acc: 0.9203 - val_loss: 0.5964 - val_acc: 0.8602
# Epoch 51/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.3901 - acc: 0.9235 - val_loss: 0.6007 - val_acc: 0.8635
# Epoch 52/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.3727 - acc: 0.9263 - val_loss: 0.6102 - val_acc: 0.8520
# Epoch 53/100
# 78/78 [==============================] - 22s 280ms/step - loss: 0.3794 - acc: 0.9219 - val_loss: 0.6008 - val_acc: 0.8470
# Epoch 54/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.3848 - acc: 0.9155 - val_loss: 0.6640 - val_acc: 0.8405
# Epoch 55/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.3532 - acc: 0.9343 - val_loss: 0.6271 - val_acc: 0.8569
# Epoch 56/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.3767 - acc: 0.9191 - val_loss: 0.7425 - val_acc: 0.7993
# Epoch 57/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.4225 - acc: 0.9103 - val_loss: 0.5681 - val_acc: 0.8734
# Epoch 58/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.3721 - acc: 0.9259 - val_loss: 0.6028 - val_acc: 0.8668
# Epoch 59/100
# 78/78 [==============================] - 22s 276ms/step - loss: 0.3249 - acc: 0.9383 - val_loss: 0.5670 - val_acc: 0.8783
# Epoch 60/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.3392 - acc: 0.9311 - val_loss: 0.5872 - val_acc: 0.8503
# Epoch 61/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.3073 - acc: 0.9443 - val_loss: 0.5962 - val_acc: 0.8766
# Epoch 62/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.4287 - acc: 0.9091 - val_loss: 0.7678 - val_acc: 0.8273
# Epoch 63/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.4090 - acc: 0.9235 - val_loss: 0.6026 - val_acc: 0.8783
# Epoch 64/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.4253 - acc: 0.9195 - val_loss: 0.5903 - val_acc: 0.8832
# Epoch 65/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.4025 - acc: 0.9271 - val_loss: 0.6183 - val_acc: 0.8734
# Epoch 66/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.3683 - acc: 0.9367 - val_loss: 0.5649 - val_acc: 0.8816
# Epoch 67/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.3417 - acc: 0.9387 - val_loss: 0.6313 - val_acc: 0.8536
# Epoch 68/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.3683 - acc: 0.9295 - val_loss: 0.6905 - val_acc: 0.8191
# Epoch 69/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.4243 - acc: 0.9127 - val_loss: 0.7666 - val_acc: 0.7829
# Epoch 70/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.6961 - acc: 0.8405 - val_loss: 1.8043 - val_acc: 0.5888
# Epoch 71/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.8168 - acc: 0.8161 - val_loss: 0.8054 - val_acc: 0.8174
# Epoch 72/100
# 78/78 [==============================] - 21s 271ms/step - loss: 0.6594 - acc: 0.8698 - val_loss: 1.1618 - val_acc: 0.6513
# Epoch 73/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.6177 - acc: 0.8838 - val_loss: 0.7245 - val_acc: 0.8487
# Epoch 74/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.5228 - acc: 0.9131 - val_loss: 0.6891 - val_acc: 0.8520
# Epoch 75/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.4445 - acc: 0.9339 - val_loss: 0.6650 - val_acc: 0.8668
# Epoch 76/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.4191 - acc: 0.9339 - val_loss: 0.6286 - val_acc: 0.8701
# Epoch 77/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.4316 - acc: 0.9203 - val_loss: 0.6082 - val_acc: 0.8668
# Epoch 78/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.3775 - acc: 0.9379 - val_loss: 0.6676 - val_acc: 0.8750
# Epoch 79/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.3594 - acc: 0.9395 - val_loss: 0.6120 - val_acc: 0.8865
# Epoch 80/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.3610 - acc: 0.9391 - val_loss: 0.7653 - val_acc: 0.8273
# Epoch 81/100
# 78/78 [==============================] - 21s 273ms/step - loss: 0.4046 - acc: 0.9283 - val_loss: 0.5504 - val_acc: 0.8931
# Epoch 82/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.4183 - acc: 0.9247 - val_loss: 3.9341 - val_acc: 0.4918
# Epoch 83/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.6151 - acc: 0.8770 - val_loss: 0.7314 - val_acc: 0.8421
# Epoch 84/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.4565 - acc: 0.9263 - val_loss: 0.6192 - val_acc: 0.8882
# Epoch 85/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.4344 - acc: 0.9275 - val_loss: 0.8224 - val_acc: 0.8191
# Epoch 86/100
# 78/78 [==============================] - 21s 269ms/step - loss: 0.4182 - acc: 0.9299 - val_loss: 0.6822 - val_acc: 0.8586
# Epoch 87/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.3891 - acc: 0.9355 - val_loss: 1.1308 - val_acc: 0.7368
# Epoch 88/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.4958 - acc: 0.9079 - val_loss: 0.6288 - val_acc: 0.8651
# Epoch 89/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.4510 - acc: 0.9243 - val_loss: 0.7096 - val_acc: 0.8536
# Epoch 90/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.3874 - acc: 0.9391 - val_loss: 0.6220 - val_acc: 0.8865
# Epoch 91/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.3531 - acc: 0.9431 - val_loss: 0.5714 - val_acc: 0.8898
# Epoch 92/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.3310 - acc: 0.9571 - val_loss: 0.8125 - val_acc: 0.7961
# Epoch 93/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.3236 - acc: 0.9523 - val_loss: 0.6214 - val_acc: 0.8865
# Epoch 94/100
# 78/78 [==============================] - 21s 272ms/step - loss: 0.2947 - acc: 0.9599 - val_loss: 0.7311 - val_acc: 0.8405
# Epoch 95/100
# 78/78 [==============================] - 21s 267ms/step - loss: 0.2828 - acc: 0.9583 - val_loss: 0.6932 - val_acc: 0.8586
# Epoch 96/100
# 78/78 [==============================] - 21s 270ms/step - loss: 0.3236 - acc: 0.9403 - val_loss: 0.8602 - val_acc: 0.7895
# Epoch 97/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.5614 - acc: 0.8782 - val_loss: 1.0427 - val_acc: 0.6891
# Epoch 98/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.8622 - acc: 0.8005 - val_loss: 1.0469 - val_acc: 0.7467
# Epoch 99/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.6561 - acc: 0.8970 - val_loss: 0.8052 - val_acc: 0.8355
# Epoch 100/100
# 78/78 [==============================] - 21s 268ms/step - loss: 0.5245 - acc: 0.9259 - val_loss: 0.7471 - val_acc: 0.8766
